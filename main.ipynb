# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install labelImg
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
import torch
model = torch.hub.load('ultralytics/yolov5', 'custom', path='yolov5s.pt', force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\USER/.cache\torch\hub\master.zip
# YOLOv5  2025-1-4 Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('yolov5\data','images')
labels = ['awake', 'drowsy']
num_img = 220

# %%
cap = cv2.VideoCapture(0)
# Loop through labels
for label in labels:
    print('Collecting images for {}'.format(label))
    time.sleep(5)
    
    # Loop through image range
    for img_num in range(num_img):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        
        # Webcam feed
        ret, frame = cap.read()
        
        # Naming out image path
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        
        # Writes out image to file 
        cv2.imwrite(imgname, frame)
        
        # Render to the screen
        cv2.imshow('Image Collection', frame)
        
        # 2 second delay between captures
        time.sleep(2)
        
        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 5
#       3 for label in labels:
#       4     print('Collecting images for {}'.format(label))
# ----> 5     time.sleep(5)
#       7     # Loop through image range
#       8     for img_num in range(num_img):
#
# KeyboardInterrupt:

# %%
print(os.path.join(IMAGES_PATH, labels[0]+'.'+str(uuid.uuid1()) + '.jpg'))
# Out:
# yolov5\data\images\awake.75b895a5-c9f9-11ef-9a0a-f426794300e3.jpg

# %%
for label in labels:
    print('Collecting images for {}'.format(label))
    for img_num in range(num_img):
        print('Collecting images for {}, image number {}'.format(label, img_num))
        imgname = os.path.join(IMAGES_PATH, label+'.'+str(uuid.uuid1())+'.jpg')
        print(imgname)
# Out:
# ...
# yolov5\data\images\awake.75ec3cd2-c9f9-11ef-9ca6-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd3-c9f9-11ef-a82c-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd4-c9f9-11ef-b0a2-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd5-c9f9-11ef-be5b-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd6-c9f9-11ef-86a2-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd7-c9f9-11ef-a26f-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd8-c9f9-11ef-b934-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cd9-c9f9-11ef-a223-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cda-c9f9-11ef-ab2b-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cdb-c9f9-11ef-8c46-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cdc-c9f9-11ef-af9f-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cdd-c9f9-11ef-a0ab-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cde-c9f9-11ef-90f2-f426794300e3.jpg
# ...
# yolov5\data\images\awake.75ec3cdf-c9f9-11ef-b3df-f426794300e3.jpg
# ...

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
# !pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resources.py resources.qrc
# Out:
# ...
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
#
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os

image_dir = 'C:/Users/USER/Documents/compvis/yolov5/data/images'
print(os.listdir(image_dir))
# Out:
# ['2023-04-27-224931.jpg', '2023-04-27-224934.jpg', '2023-04-27-224940.jpg', '2023-04-27-224947.jpg', '2023-04-27-224956.jpg', '2023-04-27-224958.jpg', '2023-04-27-225001.jpg', '2023-04-27-225010.jpg', '2023-04-27-225028.jpg', '2023-04-27-225041.jpg', '2023-04-27-225054.jpg', '2023-04-27-225056.jpg', '2023-04-27-225104.jpg', '2023-04-27-225108.jpg', '2023-04-27-225110.jpg', '2023-04-27-225112.jpg', '2023-04-27-225116.jpg', '2023-04-27-225142.jpg', '2023-04-27-225153.jpg', '2023-04-27-225201.jpg', '2023-04-27-230019.jpg', '2023-04-27-230125.jpg', '2023-04-27-230151.jpg', '2023-04-27-230219.jpg', '2023-04-27-230225.jpg', '2023-04-27-230235.jpg', '2023-04-27-230253.jpg', '2023-04-27-230313.jpg', '2023-04-27-230320.jpg', '2023-04-27-230328.jpg', '2023-04-27-230332.jpg', '2023-04-27-230400.jpg', '2023-04-27-230404.jpg', '2023-04-27-230410.jpg', '2023-04-27-230616.jpg', '2023-04-27-230659.jpg', '2023-04-27-230721.jpg', '2023-04-27-230727.jpg', '2023-04-27-231020.jpg', '2023-04-27-231027.jpg
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 8 --epochs 100 --data dataset.yml --weights yolov5s.pt
# Out:
# Error decoding JSON from C:\Users\USER\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\USER\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Error decoding JSON from C:\Users\USER\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\USER\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...

# %%
model = torch.hub.load('ultralytics/yolov5','custom',path = 'yolov5/runs/train/exp42/weights/last.pt',force_reload=True)
# Out:
# Downloading: "https://github.com/ultralytics/yolov5/zipball/master" to C:\Users\USER/.cache\torch\hub\master.zip
# YOLOv5  2025-1-4 Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7055974 parameters, 0 gradients, 15.9 GFLOPs
# Adding AutoShape...

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    results = model(frame)
    cv2.imshow('YOLO', np.squeeze(results.render()))
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
    
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 5
#       2 while cap.isOpened():
#       3     ret, frame = cap.read()
# ----> 5     results = model(frame)
#       6     cv2.imshow('YOLO', np.squeeze(results.render()))
#       8     if cv2.waitKey(10) & 0xFF == ord('q'):
#
# File c:\Users\USER\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\nn\modules\module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# ...
