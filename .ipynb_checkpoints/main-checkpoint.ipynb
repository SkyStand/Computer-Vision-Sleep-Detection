# %%
# !pip3 install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5 & pip install -r requirements.txt
# Out:
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...

# %%
import torch 
import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
model = torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\USER/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2024-10-25 Python-3.11.3 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 6144MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
model
# Out:
# AutoShape(
#   (model): DetectMultiBackend(
#     (model): DetectionModel(
#       (model): Sequential(
#         (0): Conv(
#           (conv): Conv2d(3, 32, kernel_size=(6, 6), stride=(2, 2), padding=(2, 2))
#           (act): SiLU(inplace=True)
#         )
#         (1): Conv(
#           (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#           (act): SiLU(inplace=True)
#         )
#         (2): C3(
#           (cv1): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv2): Conv(
#             (conv): Conv2d(64, 32, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (cv3): Conv(
#             (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#             (act): SiLU(inplace=True)
#           )
#           (m): Sequential(
#             (0): Bottleneck(
#               (cv1): Conv(
# ...

# %%
# cap = cv2.VideoCapture(0)
# while cap.isOpened():
#     ret, frame = cap.read()
    
#     results = model(frame)
#     cv2.imshow('YOLO', np.squeeze(results.render()))
    
#     if cv2.waitKey(10) & 0xFF == ord('q'):
#         break
    
# cap.release()
# cv2.destroyAllWindows()

# %%
import uuid
import os
import time

# %%
IMAGES_PATH = os.path.join('data','images')
labels = ['awake', 'drowsy']
num_img = 50

# %%
for label in labels: 
    print('Collecting images for {}'.format(label))
    for i in range(num_img):
        print('Collecting images for {}, image number {}'.format(label, i))
        imgname = os.path.join(IMAGES_PATH, label + '.' + str(uuid.uuid1()) + '.jpg')
        print(imgname)
# Out:
# ...
# data\images\awake.350b3d86-9239-11ef-b144-f426794300e3.jpg
# ...
# data\images\awake.350b64fc-9239-11ef-a297-f426794300e3.jpg
# ...
# data\images\awake.350b64fd-9239-11ef-ab8f-f426794300e3.jpg
# ...
# data\images\awake.350b64fe-9239-11ef-99d8-f426794300e3.jpg
# ...
# data\images\awake.350b64ff-9239-11ef-87b1-f426794300e3.jpg
# ...
# data\images\awake.350b6500-9239-11ef-b8dd-f426794300e3.jpg
# ...
# data\images\awake.350b6501-9239-11ef-9900-f426794300e3.jpg
# ...
# data\images\awake.350b6502-9239-11ef-a7e1-f426794300e3.jpg
# ...
# data\images\awake.350b6503-9239-11ef-b171-f426794300e3.jpg
# ...
# data\images\awake.350b6504-9239-11ef-bae0-f426794300e3.jpg
# ...
# data\images\awake.350b6505-9239-11ef-bdc8-f426794300e3.jpg
# ...
# data\images\awake.350b6506-9239-11ef-b05f-f426794300e3.jpg
# ...
# data\images\awake.350b6507-9239-11ef-a8ae-f426794300e3.jpg
# ...
# data\images\awake.350b6508-9239-11ef-9494-f426794300e3.jpg
# ...
# data\images\awake.350b6509-9239-11ef-bead-f426794300e3.jpg
# ...
# data\images\awake.350b650a-9239-11ef-8c8f-f426794300e3.jpg
# ...

# %%
# !git clone https://github.com/HumanSignal/labelImg
# Out:
# Cloning into 'labelImg'...

# %%
# %pip install pyqt5 lxml --upgrade
# !cd labelImg && pyrcc5 -o libs/resource.py resources.qrc
# Out:
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Loading egg at c:\users\user\appdata\local\programs\python\python311\lib\site-packages\tortoise-2.3.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation. Discussion can be found at https://github.com/pypa/pip/issues/12330
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    ------ --------------------------------- 1.0/6.9 MB 5.0 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.8/6.9 MB 4.4 MB/s eta 0:00:02
#    --------------- ------------------------ 2.6/6.9 MB 4.1 MB/s eta 0:00:02
#    ------------------ --------------------- 3.1/6.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------- ----------------- 3.9/6.9 MB 3.8 MB/s eta 0:00:01
#    --------------------------- ------------ 4.7/6.9 MB 3.9 MB/s eta 0:00:01
# ...

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 5 --data yolov5/dataset.yaml --weights yolov5s.pt --workers 2
